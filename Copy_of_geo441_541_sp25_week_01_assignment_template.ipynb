# %% [markdown]
# <a href="https://colab.research.google.com/github/DestroyerDay/Geo441-Final-Project/blob/main/Copy_of_geo441_541_sp25_week_01_assignment_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441B/541B Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# 🚀 Created by [Noah Brunskill]
#
# [02/11/2025]

# %% [markdown]
# ### **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to my own Google Drive

# %% [markdown]
# ### **Map #1: Hugo Roads and Lakes**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](https://miamioh.instructure.com/courses/227178/files/34576429?wrap=1)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Check if you have your first map (*Hugo Roads and Lakes*) generated following the direction in a Google Drive folder
#    - Make sure the PNG file is accessible to anyone with a link
#    - Copy the shareable link

# %% [markdown]
# 3. **Obtain a shareable link**
#
#   - [Noah Lakes and Roads](file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/Layout.png)
#
#   - The PNG file doesn't want to link so here it is:
#   -` file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/Layout.png `

# %% [markdown]
# 5. **Insert Map**

# %% [markdown]
# # ![map 1.png](data:image/png;base64,...)

# %% [markdown]
# ### **Map #2: Cloquet Forestry Center**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](https://miamioh.instructure.com/courses/227178/files/34576429?wrap=1)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Check if you have your second map (*Cloquet Forestry Center*) generated following the direction in a Google Drive folder
#    - Make sure the PNG file is accessible to anyone with a link
#    - Copy the shareable link

# %% [markdown]
# 3. **Obtain a shareable link**
#
#   - [Wetlands](file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/Layout%202.png)
#
#   `(file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/Layout%202.png)`

# %% [markdown]
# 5. **Insert Map**
# ![Layout 2.png](data:image/png;base64,...)

# %% [markdown]
# ### **Map #3: Cloquet Vegetation Polygons**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](https://miamioh.instructure.com/courses/227178/files/34576429?wrap=1)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Check if you have your third map (*Cloquet Vegetation Polygons*) generated following the direction in a Google Drive folder
#    - Make sure the PNG file is accessible to anyone with a link
#    - Copy the shareable link

# %% [markdown]
# 3. **Link**
#  The legend wasn't working, it said some other file was open and it error coded.
#
#
#   -[Forest](file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/lay%204.png)
#   `file:///C:/Users/noahb_ks6ppc8/Desktop/assignment%201%20GIS/lay%204.png`

# %% [markdown]
# ![lay 4.png](data:image/png;base64,...)

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent [3] to finish creating all three maps

# %% [markdown]
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | [Map Creation]     | [Google Colab]  |

# %% [markdown]
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - [I think once I found how to import a file it was pretty self explanatory. I like lots of images and such, so that being in the assignment helped. ]
#   - Map creation and annotation
#     - [I think it went well, but I am a bit sloppy in terms of design, so I will probably get points of in the future for that.]
#   - Navigate the software using its GUI
#     - [I still am struggling with Google Colab and getting that organized in a nice manner. ArcGIS I think went alright, the images helped me to navigate the software easily, instead of having to look around for hours trying to find a button or function.]

# %% [markdown]
# ### **Save and share this notebook**
#
# - Make this notebook viewable by anyone with the link
#
# ![Share Notebook](https://drive.google.com/uc?export=view&id=1K4a3saeAXrzKcB4fkivkjUmLLWJ1R7oS)
#
# - Copy this link as your submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
# - [Insert other references if any]

# %% [markdown]
# ::
